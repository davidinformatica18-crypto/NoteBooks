# %% [markdown]
# # Exploración, limpieza y transformación de datos con Pandas
#
# En este notebook vas a:
# 1. Cargar un dataset de tu elección
# 2. Explorar su estructura y contenido
# 3. Detectar problemas comunes en los datos
# 4. Aplicar técnicas de limpieza
# 5. Realizar transformaciones básicas
# 6. Elaborar un pequeño informe de conclusiones
#
# Notebook generado automáticamente el 2026-03-09

# %% [markdown]
# ## 1. Importar librerías

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## 2. Cargar el dataset
#
# Descarga un dataset en formato CSV (por ejemplo desde Kaggle, datos abiertos, etc.) y colócalo en la misma carpeta que este notebook.
#
# Modifica el nombre del archivo en la siguiente celda.

# %%
file_path = ("disney_movies.csv")  # Cambia este nombre
df = pd.read_csv(file_path)
df.head(30)
# Out:
#                                movie_title release_date      genre  \
# 0          Snow White and the Seven Dwarfs   1937-12-21    Musical
# 1                                Pinocchio   1940-02-09  Adventure
# 2                                 Fantasia   1940-11-13    Musical
# 3                        Song of the South   1946-11-12  Adventure
# 4                               Cinderella   1950-02-15      Drama
# 5             20,000 Leagues Under the Sea   1954-12-23  Adventure
# 6                       Lady and the Tramp   1955-06-22      Drama
# 7                          Sleeping Beauty   1959-01-29      Drama
# 8                           101 Dalmatians   1961-01-25     Comedy
# 9              The Absent Minded Professor   1961-03-16     Comedy
# 10                        Babes in Toyland   1961-12-14    Musical
# 11                             Bon Voyage!   1962-05-17     Comedy
# 12                  The Sword in the Stone   1963-12-25  Adventure
# ...

# %% [markdown]
# ## 3. Exploración inicial del dataset

# %%
# Número de filas y columnas
df.shape
# Out:
# (579, 6)

# %%
# Información general del dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 579 entries, 0 to 578
# Data columns (total 6 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   movie_title               579 non-null    object
#  1   release_date              579 non-null    object
#  2   genre                     562 non-null    object
#  3   mpaa_rating               523 non-null    object
#  4   total_gross               579 non-null    int64
#  5   inflation_adjusted_gross  579 non-null    int64
# dtypes: int64(2), object(4)
# memory usage: 27.3+ KB

# %%
# Estadísticas básicas
df.describe()
# Out:
#         total_gross  inflation_adjusted_gross
# count  5.790000e+02              5.790000e+02
# mean   6.470179e+07              1.187625e+08
# std    9.301301e+07              2.860853e+08
# min    0.000000e+00              0.000000e+00
# 25%    1.278886e+07              2.274123e+07
# 50%    3.070245e+07              5.515978e+07
# 75%    7.570903e+07              1.192020e+08
# max    9.366622e+08              5.228953e+09

# %% [markdown]
# ### Preguntas de exploración
#
# - ¿Cuántas variables tiene el dataset?
# - ¿Qué tipo de datos contiene?
# - ¿Qué variables parecen más interesantes?
# - ¿Hay columnas categóricas?

# %% [markdown]
# ## 4. Detectar problemas en los datos

# %% [markdown]
# ### Valores nulos

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# movie_title                 0
# release_date                0
# genre                       0
# mpaa_rating                 0
# total_gross                 0
# inflation_adjusted_gross    0
# dtype: int64

# %% [markdown]
# ### Duplicados

# %%
# df.duplicated().sum()
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [movie_title, release_date, genre, mpaa_rating, total_gross, inflation_adjusted_gross]
# Index: []

# %% [markdown]
# ### Tipos de datos

# %%
df['release_date'] = pd.to_datetime(df['release_date'])
df.dtypes
# Out:
# movie_title                         object
# release_date                datetime64[ns]
# genre                               object
# mpaa_rating                         object
# total_gross                          int64
# inflation_adjusted_gross             int64
# dtype: object

# %% [markdown]
# ## 5. Limpieza de datos
#
# Aplica algunas de las siguientes técnicas según tu dataset.

# %% [markdown]
# ### Tratar valores nulos

# %%
# Ejemplo: reemplazar valores nulos por la media
# df['columna'] = df['columna'].fillna(df['columna'].mean())
df['movie_title'] = df['movie_title'].fillna("Unknown")
df['genre'] = df['genre'].fillna("Unknown")
df['mpaa_rating'] = df['mpaa_rating'].fillna("Not Rated")

df.isnull().sum()
df.head()
# Out:
#                        movie_title release_date      genre mpaa_rating  \
# 0  Snow White and the Seven Dwarfs   1937-12-21    Musical           G
# 1                        Pinocchio   1940-02-09  Adventure           G
# 2                         Fantasia   1940-11-13    Musical           G
# 3                Song of the South   1946-11-12  Adventure           G
# 4                       Cinderella   1950-02-15      Drama           G
#
#    total_gross  inflation_adjusted_gross  release_year
# 0    184925485                5228953251          1937
# 1     84300000                2188229052          1940
# 2     83320000                2187090808          1940
# 3     65000000                1078510579          1946
# 4     85000000                 920608730          1950

# %% [markdown]
# ### Eliminar duplicados

# %%
# df = df.drop_duplicates()
# df = df.drop_duplicates('movie_title')
df = df.drop_duplicates(subset='movie_title')

df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### Corregir tipos de datos

# %%
# df['columna'] = pd.to_numeric(df['columna'])
df['release_date'] = pd.to_datetime(df['release_date'])

df.dtypes
df.head()
# Out:
#                        movie_title release_date      genre mpaa_rating  \
# 0  Snow White and the Seven Dwarfs   1937-12-21    Musical           G
# 1                        Pinocchio   1940-02-09  Adventure           G
# 2                         Fantasia   1940-11-13    Musical           G
# 3                Song of the South   1946-11-12  Adventure           G
# 4                       Cinderella   1950-02-15      Drama           G
#
#    total_gross  inflation_adjusted_gross  release_year
# 0    184925485                5228953251          1937
# 1     84300000                2188229052          1940
# 2     83320000                2187090808          1940
# 3     65000000                1078510579          1946
# 4     85000000                 920608730          1950

# %% [markdown]
# ## 6. Transformaciones de datos

# %% [markdown]
# ### Crear nuevas columnas

# %%
# df['nueva_columna'] = df['col1'] + df['col2']
df['release_year'] = df['release_date'].dt.year
df[['release_date', 'release_year']].head()
# Out:
#   release_date  release_year
# 0   1937-12-21          1937
# 1   1940-02-09          1940
# 2   1940-11-13          1940
# 3   1946-11-12          1946
# 4   1950-02-15          1950

# %% [markdown]
# ### Filtrar datos

# %%
# df_filtrado = df[df['columna'] > 10]
# df_filtrado.head()

df_filtrado = df[df['total_gross'] > 100000000]

df_filtrado.head()
# Out:
#                         movie_title release_date    genre mpaa_rating  \
# 0   Snow White and the Seven Dwarfs   1937-12-21  Musical           G
# 8                    101 Dalmatians   1961-01-25   Comedy           G
# 13                  The Jungle Book   1967-10-18  Musical   Not Rated
# 60                 3 Men and a Baby   1987-11-25   Comedy          PG
# 61             Good Morning Vietnam   1987-12-23   Comedy           R
#
#     total_gross  inflation_adjusted_gross  release_year
# 0     184925485                5228953251          1937
# 8     153000000                1362870985          1961
# 13    141843000                 789612346          1967
# 60    167780960                 353334607          1987
# 61    123922370                 254414837          1987

# %% [markdown]
# ## 7. Informe de conclusiones
#
# Responde a las siguientes preguntas en tus propias palabras:
#
# 1. ¿Qué dataset has utilizado y qué información contiene?
#
# ## He utilizado un dataset sobre películas de Disney.
# ## título de la película, la fecha de estreno, el género, la clasificación por edad y los ingresos en taquilla
#
# 2. ¿Cuántos registros y variables tiene?
#
# ## 579 registros (filas) y 6 variables (columnas)
#
# 3. ¿Qué problemas encontraste en los datos?
#
# ## valores nulos en algunas columnas
#
# 4. ¿Qué técnicas de limpieza aplicaste?
#
# ## Verificación de duplicados
#
# 5. ¿Qué transformaciones realizaste?
#
# ## Agrupación de datos por año y genero
#
# 6. ¿Qué conclusiones interesantes has encontrado al analizar los datos?
#
# ## Los estrenos recientes suelen tener una menor recaudación.
#
# Escribe tus respuestas en una o varias celdas Markdown.
#
# ## Se observar la evolución del éxito comercial de Disney y como en cada época influyen en la recaudación.
